# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
working_path = '/Users/sinsakuokazaki/Project/pred-future-sales'
sales_train_path = ''

# %%
train = pd.read_csv('/Users/sinsakuokazaki/Project/pred-future-sales/\
input/competitive-data-science-predict-future-sales/sales_train.csv')

train_total = pd.read_csv('/Users/sinsakuokazaki/Project/pred-future-sales/\
input/competitive-data-science-predict-future-sales/train_total.csv')

test = pd.read_csv('/Users/sinsakuokazaki/Project/pred-future-sales/\
input/competitive-data-science-predict-future-sales/test.csv')

item_categories = pd.read_csv('/Users/sinsakuokazaki/Project/pred-future-sales/\
input/competitive-data-science-predict-future-sales/item_categories.csv')

items = pd.read_csv('/Users/sinsakuokazaki/Project/pred-future-sales/\
input/competitive-data-science-predict-future-sales/items.csv')

shops = pd.read_csv('/Users/sinsakuokazaki/Project/pred-future-sales/\
input/competitive-data-science-predict-future-sales/shops.csv')

# %%
items_categories = pd.merge(items, item_categories, how = "outer", on = 'item_category_id')

# %%
items_categories.head()
# Out:
#                                            item_name  item_id  \
# 0          ! ВО ВЛАСТИ НАВАЖДЕНИЯ (ПЛАСТ.)         D        0
# 1      ***В ЛУЧАХ СЛАВЫ   (UNV)                    D        2
# 2    ***ГОЛУБАЯ ВОЛНА  (Univ)                      D        3
# 3        ***КОРОБКА (СТЕКЛО)                       D        4
# 4  ***НОВЫЕ АМЕРИКАНСКИЕ ГРАФФИТИ  (UNI)         ...        5
#
#    item_category_id item_category_name
# 0                40         Кино - DVD
# 1                40         Кино - DVD
# 2                40         Кино - DVD
# 3                40         Кино - DVD
# 4                40         Кино - DVD

# %%
items_categories.to_csv('/Users/sinsakuokazaki/Project/pred-future-sales/\
input/competitive-data-science-predict-future-sales/items_categories.csv', index = False)

# %%
train = pd.merge(train, shops, how ="left", on = "shop_id")

# %%
train = pd.merge(train, items_categories, how = "left", on = "item_id")

# %%
train.head()
# Out:
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day  \
# 0  2013-01-02               0       59    22154      999.00           1.0
# 1  2013-01-03               0       25     2552      899.00           1.0
# 2  2013-01-05               0       25     2552      899.00          -1.0
# 3  2013-01-06               0       25     2554     1709.05           1.0
# 4  2013-01-15               0       25     2555     1099.00           1.0
#
#    dayofweek  dayofmonth  month  quarter  year  minute  hour  total_sales  \
# 0          2           2      1        1  2013       0     0       999.00
# 1          3           3      1        1  2013       0     0       899.00
# 2          5           5      1        1  2013       0     0      -899.00
# 3          6           6      1        1  2013       0     0      1709.05
# 4          1          15      1        1  2013       0     0      1099.00
#
#                 shop_name                                 item_name  \
# ...

# %%
train.to_csv('/Users/sinsakuokazaki/Project/pred-future-sales/\
input/competitive-data-science-predict-future-sales/sales_train.csv', index = False)

# %%
train_tortal.columns
# Out:
# Index(['shop_id', 'item_id', 'total_sales-1-2013', 'total_sales-2-2013',
#        'total_sales-3-2013', 'total_sales-4-2013', 'total_sales-5-2013',
#        'total_sales-6-2013', 'total_sales-7-2013', 'total_sales-8-2013',
#        'total_sales-9-2013', 'total_sales-10-2013', 'total_sales-11-2013',
#        'total_sales-12-2013', 'total_sales-1-2014', 'total_sales-2-2014',
#        'total_sales-3-2014', 'total_sales-4-2014', 'total_sales-5-2014',
#        'total_sales-6-2014', 'total_sales-7-2014', 'total_sales-8-2014',
#        'total_sales-9-2014', 'total_sales-10-2014', 'total_sales-11-2014',
#        'total_sales-12-2014', 'total_sales-1-2015', 'total_sales-2-2015',
#        'total_sales-3-2015', 'total_sales-4-2015', 'total_sales-5-2015',
#        'total_sales-6-2015', 'total_sales-7-2015', 'total_sales-8-2015',
#        'total_sales-9-2015', 'total_sales-10-2015', 'total_sales-11-2015',
#        'total_sales-12-2015'],
#       dtype='object')

# %%
train_total = pd.merge(train_total, items_categories, how = "left", on="item_id")

# %%
train_total = pd.merge(train_total, shops, how= "left", on ="shop_id")

# %%
train_total.to_csv('/Users/sinsakuokazaki/Project/pred-future-sales/\
input/competitive-data-science-predict-future-sales/train_total.csv', index = False)

# %%
test.head()
# Out:
#    ID  shop_id  item_id
# 0   0        5     5037
# 1   1        5     5320
# 2   2        5     5233
# 3   3        5     5232
# 4   4        5     5268

# %%
test = pd.merge(test, items_categories, how = 'left', on = 'item_id')
test = pd.merge(test, shops, how = 'left', on = 'shop_id')

# %%
test.head()
# Out:
#    ID  shop_id  item_id                                          item_name  \
# 0   0        5     5037                     NHL 15 [PS3, русские субтитры]
# 1   1        5     5320                    ONE DIRECTION  Made In The A.M.
# 2   2        5     5233  Need for Speed Rivals (Essentials) [PS3, русск...
# 3   3        5     5232  Need for Speed Rivals (Classics) [Xbox 360, ру...
# 4   4        5     5268               Need for Speed [PS4, русская версия]
#
#    item_category_id                   item_category_name  \
# 0                19                           Игры - PS3
# 1                55  Музыка - CD локального производства
# 2                19                           Игры - PS3
# 3                23                      Игры - XBOX 360
# 4                20                           Игры - PS4
#
#                 shop_name
# 0  Вологда ТРЦ "Мармелад"
# 1  Вологда ТРЦ "Мармелад"
# 2  Вологда ТРЦ "Мармелад"
# 3  Вологда ТРЦ "Мармелад"
# 4  Вологда ТРЦ "Мармелад"

# %%
test.to_csv('/Users/sinsakuokazaki/Project/pred-future-sales/\
input/competitive-data-science-predict-future-sales/test.csv', index = False)
