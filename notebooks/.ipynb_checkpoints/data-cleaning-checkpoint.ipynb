# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv('~/Project/pred-future-sales/raw/sales_train.csv')

test = pd.read_csv('/Users/sinsakuokazaki/Project/pred-future-sales/\
input/competitive-data-science-predict-future-sales/test.csv')

# %%
type(train.date[0])
# Out:
# str

# %%
train['date'] = pd.to_datetime(train['date'], format='%Y-%m-%d')

# %%
plt.figure(figsize=(15, 8))
ax = sns.lineplot(x = 'date', y = 'item_cnt_day', data = train)
plt.xlabel("date")
plt.ylabel('number of items sold')
# Out:
# Text(0,0.5,'number of items sold')

# %%
sold_over_10 = train.loc[train['item_cnt_day'] > 10]

# %%
plt.figure(figsize=(15, 8))
ax = sns.lineplot(x = 'date', y = 'item_cnt_day', data = sold_over_10)
plt.xlabel("date")
plt.ylabel('number of items sold')
# Out:
# Text(0,0.5,'number of items sold')

# %%
train['total_sales'] = train['item_price'] * train['item_cnt_day']

# %%
train.head()
# Out:
#         date  date_block_num  shop_id  item_id  item_price  item_cnt_day  \
# 0 2013-01-02               0       59    22154      999.00           1.0
# 1 2013-01-03               0       25     2552      899.00           1.0
# 2 2013-01-05               0       25     2552      899.00          -1.0
# 3 2013-01-06               0       25     2554     1709.05           1.0
# 4 2013-01-15               0       25     2555     1099.00           1.0
#
#    dayofweek  dayofmonth  month  quarter  year  minute  hour  total_sales
# 0          2           2      1        1  2013       0     0       999.00
# 1          3           3      1        1  2013       0     0       899.00
# 2          5           5      1        1  2013       0     0      -899.00
# 3          6           6      1        1  2013       0     0      1709.05
# 4          1          15      1        1  2013       0     0      1099.00

# %%
dfs = []
for y in train['year'].unique():
    for m in train['month'].unique():
        df = pd.DataFrame(train.loc[(train['year'] == y) & (train['month'] == m)]
                          .groupby(['shop_id', 'item_id'])['total_sales'].sum())
        df = df.rename(index=str, columns={'total_sales': 'total_sales-'+ str(m) + '-' + str(y)})
        df.reset_index(inplace=True)
        dfs.append(df)

# %%
train_total = dfs[0]
for df in dfs[1:]:
    train_total =  pd.merge(train_total, df, how='outer', on=['shop_id', 'item_id'])

# %%
train_total.head()
# Out:
#   shop_id item_id  total_sales-1-2013  total_sales-2-2013  total_sales-3-2013  \
# 0       0      32              1326.0              2210.0                 NaN
# 1       0      33              1041.0              1041.0                 NaN
# 2       0      35               247.0              3458.0                 NaN
# 3       0      43               221.0                 NaN                 NaN
# 4       0      51               257.0               381.0                 NaN
#
#    total_sales-4-2013  total_sales-5-2013  total_sales-6-2013  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
#
#    total_sales-7-2013  total_sales-8-2013         ...           \
# 0                 NaN                 NaN         ...
# 1                 NaN                 NaN         ...
# 2                 NaN                 NaN         ...
# 3                 NaN                 NaN         ...
# 4                 NaN                 NaN         ...
#
#    total_sales-3-2015  total_sales-4-2015  total_sales-5-2015  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
#
#    total_sales-6-2015  total_sales-7-2015  total_sales-8-2015  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
#
#    total_sales-9-2015  total_sales-10-2015  total_sales-11-2015  \
# 0                 NaN                  NaN                  NaN
# 1                 NaN                  NaN                  NaN
# 2                 NaN                  NaN                  NaN
# 3                 NaN                  NaN                  NaN
# 4                 NaN                  NaN                  NaN
#
#    total_sales-12-2015
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#
# [5 rows x 38 columns]

# %%
train_total.to_csv('/Users/sinsakuokazaki/Project/pred-future-sales/\
input/competitive-data-science-predict-future-sales/train_total.csv', index = False)

# %%
train.to_csv('/Users/sinsakuokazaki/Project/pred-future-sales/\
input/competitive-data-science-predict-future-sales/sales_train.csv', index = False)
